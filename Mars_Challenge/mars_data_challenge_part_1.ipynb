# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import numpy as np

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|█████████████████| 8.41M/8.41M [00:01<00:00, 7.06MB/s]

# %%
url = 'https://redplanetscience.com/'
browser.visit(url)
html = browser.html
quote_soup = soup(html, 'html.parser')

# %%
# Scrape all quotes on a scrape the title and preview text image_and_description_container
quote_soup
# Out:
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# ...

# %%
# Scrape website for titles of articles. 
title = []
title = quote_soup.find_all('div', class_='content_title')
titles =  [i.get_text() for i in title]
titles
# Out:
# ['NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch',
#  'The MarCO Mission Comes to an End',
#  "NASA's Mars Rover Drivers Need Your Help",
#  'Two of a Space Kind: Apollo 12 and Mars 2020',
#  'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#  'New Selfie Shows Curiosity, the Mars Chemist',
#  "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#  "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound",
#  'NASA Invites Students to Name Mars 2020 Rover',
#  "NASA's Perseverance Mars Rover Gets Balanced",
#  'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team',
#  'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020',
#  "NASA's MAVEN Explores Mars to Understand Radio Interference at Earth",
#  'MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss',
#  "5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover"]

# %%
#Scrape website for article summary text
content_summary=[]
content_summary = quote_soup.find_all('div',class_='article_teaser_body')
content_summary = [i.get_text() for i in content_summary]
content_summary
# Out:
# ['There are lots of ways to participate in the historic event, which is targeted for July 30.',
#  'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.',
#  'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.',
#  'For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars. ',
#  'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.',
#  'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.',
# ...

# %%
#Create a dictionary from the titles and content_summary
mars_news = {}

for i in range(0, len(titles)):
    mars_news[titles[i]] = content_summary[i]
    
print(mars_news)
# Out:
# {'NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch': 'There are lots of ways to participate in the historic event, which is targeted for July 30.', 'The MarCO Mission Comes to an End': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.', "NASA's Mars Rover Drivers Need Your Help": 'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.', 'Two of a Space Kind: Apollo 12 and Mars 2020': 'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.', 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen': 'For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars. ', 
# ...

# %%
mars_news
# Out:
# {'NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch': 'There are lots of ways to participate in the historic event, which is targeted for July 30.',
#  'The MarCO Mission Comes to an End': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  "NASA's Mars Rover Drivers Need Your Help": 'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.',
#  'Two of a Space Kind: Apollo 12 and Mars 2020': 'Apollo 12 and the upcoming Mars 2020 mission may be separated by half a century, but they share several goals unique in the annals of space exploration.',
# ...

# %%
import json

# %%
mars_df = pd.DataFrame(mars_news, index=[0])
mars_df
# Out:
#   NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch  \
# 0  There are lots of ways to participate in the h...
#
#                    The MarCO Mission Comes to an End  \
# 0  The pair of briefcase-sized satellites made hi...
#
#             NASA's Mars Rover Drivers Need Your Help  \
# 0  Using an online tool to label Martian terrain ...
#
#         Two of a Space Kind: Apollo 12 and Mars 2020  \
# 0  Apollo 12 and the upcoming Mars 2020 mission m...
#
#   With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen  \
# 0  For the first time in the history of space exp...
#
#         New Selfie Shows Curiosity, the Mars Chemist  \
# 0  The NASA rover performed a special chemistry e...
#
#       NASA's InSight 'Hears' Peculiar Sounds on Mars  \
# 0  Listen to the marsquakes and other, less-expec...
#
#   NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound  \
# ...

# %%
mars_df.to_json(r'Mars-Challenge\mars_news_df.json')

# %%
browser.quit()
